# %% [markdown]
# First method: 3 atlases for 3 scanners

# %% [markdown]
# Elastix
# registration of dataset of scanner 1

# %%
import subprocess
import os

# Define paths
elastix_path = '/Users/melikapooyan/Documents/elastix-5.0/elastix'  # Path to the Elastix executable
fixed_image_path = '/Users/melikapooyan/Documents/elastix-5.0/IBSR_01/IBSR_01.nii.gz'  # Path to the fixed image

# List of moving images
moving_image_paths = [
    '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_03/IBSR_03.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_04/IBSR_04.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_05/IBSR_05.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_06/IBSR_06.nii.gz'
]

output_dir_base = '/Users/melikapooyan/Documents/elastix-5.0/'  # Base output directory
param_file_path1 = '/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt'  # Path to the first parameter file
param_file_path2 = '/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt'  # Path to the second parameter file

for moving_image_path in moving_image_paths:
    # Extract the identifier of the moving image for the output directory
    moving_image_identifier = os.path.basename(moving_image_path).split('.')[0].split('_')[1]
    output_dir = os.path.join(output_dir_base, f'resIBSR_{moving_image_identifier}')

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the Elastix command with two parameter files
    command = [
        elastix_path,
        '-f', fixed_image_path,
        '-m', moving_image_path,
        '-out', output_dir,
        '-p', param_file_path1,
        '-p', param_file_path2
    ]

    # Execute the Elastix command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Print the output for debugging
    print(f"Registration of IBSR_{moving_image_identifier}")
    print(result.stdout)

    # Check if Elastix ran successfully
    if result.returncode == 0:
        print('Elastix registration completed successfully.')
    else:
        print('Elastix registration failed.')
        print(result.stderr)
# Out:
# Registration of IBSR_03
#
# elastix is started at Tue Jan  2 18:39:31 2024.
#
# which elastix:   /Users/melikapooyan/Documents/elastix-5.0/elastix
# elastix runs at: pc-8-91.customer.ask4.lan
#   macOS 14.0 (x64), 23A344
#   with 16384 MB memory, and 8 cores @ 2400 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt".
#
# Current time: Tue Jan  2 18:39:31 2024.
# Reading the elastix parameters from file ...
#
# Installing all components.
# InstallingComponents was successful.
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        /Users/melikapooyan/Documents/elastix-5.0/IBSR_01/IBSR_01.nii.gz
# -m        /Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_03/IBSR_03.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      /Users/melikapooyan/Documents/elastix-5.0/resIBSR_03/
# -p        /Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt
# -p        /Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt
# -threads  unspecified, so all available threads are used
# WARNING: The parameter "UseDirectionCosines", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# WARNING: The option "UseDirectionCosines" was not found in your parameter file.
#   From elastix 4.8 it defaults to true!
# This may change the behavior of your registrations considerably.
#
# Command line options from TransformBase:
# -t0       unspecified, so no initial transform used
#
# Reading images...
# Reading images took 107 ms.
#
# WARNING: the fixed pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: the moving pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: The parameter "AutomaticTransformInitializationMethod", requested at entry number 0, does not exist at all.
#   The default value "GeometricalCenter" is used instead.
# Transform parameters are initialized as: [1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0]
# InitializeTransform took 0.00s
# WARNING: The parameter "AutomaticScalesEstimation", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Scales for transform parameters are: [50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 1, 1, 1]
# Initialization of all components (before registration) took: 3 ms.
# Preparation of the image pyramids took: 251 ms.
#
# Resolution: 0
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 0, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 2 ms.
#   Computing the fixed image extrema took 1 ms.
#   Computing the moving image extrema took 0 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 8 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.362154	4.000000	0.659613	21.9
# 1	-0.384618	2.000000	0.879208	11.5
# 2	-0.391622	1.000000	0.845277	11.8
# 3	-0.403141	0.500000	0.902393	11.0
# Time spent in resolution 0 (ITK initialization and iterating): 0.068 s.
# Stopping condition: Minimum step size has been reached.
#
# Resolution: 1
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 1, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 1 ms.
#   Computing the moving image extrema took 1 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 43 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.379756	2.000000	0.882992	77.8
# 1	-0.387520	1.000000	0.750696	31.4
# 2	-0.395047	1.000000	0.759689	30.1
# 3	-0.399424	0.500000	0.753347	29.3
# 4	-0.402316	0.250000	0.739542	29.8
# 5	-0.405300	0.250000	0.726732	29.6
# 6	-0.407257	0.125000	0.751919	28.8
# 7	-0.408691	0.125000	0.753291	29.1
# 8	-0.410603	0.125000	0.755659	30.0
# 9	-0.412283	0.125000	0.748420	30.0
# 10	-0.415381	0.062500	0.722391	28.9
# Time spent in resolution 1 (ITK initialization and iterating): 0.405 s.
# Stopping condition: Minimum step size has been reached.
#
# Resolution: 2
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 2, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 11 ms.
#   Computing the moving image extrema took 10 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 349 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.368168	2.000000	0.517740	402.1
# 1	-0.371292	1.000000	0.230372	48.2
# 2	-0.379443	1.000000	0.251990	49.1
# 3	-0.382015	0.500000	0.252068	55.6
# 4	-0.382343	0.250000	0.205435	51.6
# 5	-0.382753	0.125000	0.205544	52.9
# 6	-0.382913	0.062500	0.191146	51.8
# 7	-0.382993	0.062500	0.195028	51.6
# Time spent in resolution 2 (ITK initialization and iterating): 0.813 s.
# Stopping condition: Minimum step size has been reached.
#
#
# Creating the TransformParameterFile took 0.00s
#
# Registration result checksum: 2570928911
# WARNING: The parameter "WriteResultImage", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# Applying final transform ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Applying final transform took 0.65s
#
# Final metric value  = -0.383141
# Time spent on saving the results, applying the final transform etc.: 649 ms.
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt", has finished.
#
#
# Current time: Tue Jan  2 18:39:34 2024.
# Time used for running elastix with this parameter file:
#   2.3s.
#
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 1: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt".
#
# Current time: Tue Jan  2 18:39:34 2024.
# Reading the elastix parameters from file ...
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        /Users/melikapooyan/Documents/elastix-5.0/IBSR_01/IBSR_01.nii.gz
# -m        /Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_03/IBSR_03.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      /Users/melikapooyan/Documents/elastix-5.0/resIBSR_03/
# -p        /Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt
# -p        /Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt
# -threads  unspecified, so all available threads are used
# WARNING: The parameter "UseDirectionCosines", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# WARNING: The option "UseDirectionCosines" was not found in your parameter file.
#   From elastix 4.8 it defaults to true!
# This may change the behavior of your registrations considerably.
#
# Command line options from TransformBase:
# -t0       unspecified, so no initial transform used
# WARNING: The parameter "BSplineTransformSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseCyclicTransform", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
#
# Reading images...
# Reading images took 0 ms.
#
# WARNING: the fixed pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: the moving pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: The parameter "GenerateLineSearchIterations", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Initialization of all components (before registration) took: 6 ms.
# Preparation of the image pyramids took: 224 ms.
#
# Resolution: 0
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "MaximumNumberOfLineSearchIterations", requested at entry number 0, does not exist at all.
#   The default value "20" is used instead.
# Elastix initialization of all components (for this resolution) took: 1 ms.
#   Computing the fixed image extrema took 0 ms.
#   Computing the moving image extrema took 0 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 5 ms.
# 1:ItNr	1a:SrchDirNr	1b:LineItNr	2:Metric	3:StepLength	4a:||Gradient||	4b:||SearchDir||	4c:DirGradient	5:Phase	6a:Wolfe1	6b:Wolfe2	7:LinSrchStopCondition	Time[ms]
# 0	0	2	-0.517914	42.000000	0.001315	1.000000	0.000400	Main	true	true	WolfeSatisfied	76.8
# 1	1	1	-0.515687	1.023228	0.000907	15.406572	0.000061	Main	true	true	WolfeSatisfied	40.5
# 2	2	0	-0.522466	2.000000	0.000951	8.852776	0.002019	Main	true	true	WolfeSatisfied	27.3
# 3	3	0	-0.528911	2.000000	0.001011	8.482768	0.002897	Main	true	true	WolfeSatisfied	26.4
# 4	4	0	-0.530400	2.000000	0.000752	9.225233	0.000395	Main	true	true	WolfeSatisfied	27.3
# 5	5	0	-0.544916	2.000000	0.001108	8.637352	0.003698	Main	true	true	WolfeSatisfied	27.4
# 6	6	0	-0.535263	2.000000	0.000954	9.888422	0.005770	Main	true	true	WolfeSatisfied	27.3
# 7	7	1	-0.532487	0.987056	0.000652	12.543584	0.000274	Main	true	true	WolfeSatisfied	40.3
# 8	8	0	-0.544107	2.000000	0.000839	6.880537	0.001025	Main	true	true	WolfeSatisfied	27.3
# 9	9	1	-0.535597	1.142542	0.000543	8.080697	-0.000055	Main	true	true	WolfeSatisfied	41.0
# 10	10	1	-0.533234	1.025031	0.000540	8.206706	-0.000004	Main	true	true	WolfeSatisfied	40.3
# 11	11	0	-0.544448	2.000000	0.001153	7.297478	0.003600	Main	true	true	WolfeSatisfied	28.4
# 12	12	1	-0.541321	1.126751	0.000504	9.238316	-0.000284	Main	true	true	WolfeSatisfied	40.3
# 13	13	0	-0.535572	2.000000	0.001015	7.980228	0.003473	Main	true	true	WolfeSatisfied	32.1
# 14	14	1	-0.541602	1.124232	0.000590	10.454586	0.000015	Main	true	true	WolfeSatisfied	42.4
# 15	15	0	-0.544036	2.000000	0.001018	6.055956	0.002832	Main	true	true	WolfeSatisfied	27.1
# 16	16	1	-0.543294	1.130977	0.000551	9.686685	-0.000737	Main	true	true	WolfeSatisfied	41.3
# Time spent in resolution 0 (ITK initialization and iterating): 0.615 s.
# Stopping condition: The gradient magnitude has (nearly) vanished.
#
# Resolution: 1
# WARNING: The parameter "ShowExactMetricValue", requested at entry number
# 22	22	1	-0.468120	1.712934	0.000806	20.307676	0.001160	Main	true	true	WolfeSatisfied	222.9
# 23	23	1	-0.466401	1.503771	0.000688	25.205236	0.002471	Main	true	true	WolfeSatisfied	220.1
# 24	24	1	-0.467909	1.602068	0.000732	26.167923	0.001825	Main	true	true	WolfeSatisfied	217.8
# Time spent in resolution 2 (ITK initialization and iterating): 5.815 s.
# Stopping condition: Maximum number of iterations has been reached.
#
#
# Creating the TransformParameterFile took 0.05s
#
# Registration result checksum: 161580305
# WARNING: The parameter "WriteResultImage", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# Applying final transform ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Applying final transform took 1.88s
#
# Final metric value  = -0.461425
# Time spent on saving the results, applying the final transform etc.: 1935 ms.
# Running elastix with parameter file 1: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt", has finished.
#
#
# Current time: Tue Jan  2 18:39:46 2024.
# Time used for running elastix with this parameter file:
#   12.1s.
#
# -------------------------------------------------------------------------
#
# Total time elapsed: 14.4s.
#
#
# Elastix registration completed successfully.
# Registration of IBSR_04
#
# elastix is started at Tue Jan  2 18:39:46 2024.
#
# which elastix:   /Users/melikapooyan/Documents/elastix-5.0/elastix
# elastix runs at: pc-8-91.customer.ask4.lan
#   macOS 14.0 (x64), 23A344
#   with 16384 MB memory, and 8 cores @ 2400 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt".
#
# Current time: Tue Jan  2 18:39:46 2024.
# Reading the elastix parameters from file ...
#
# Installing all components.
# InstallingComponents was successful.
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        /Users/melikapooyan/Documents/elastix-5.0/IBSR_01/IBSR_01.nii.gz
# -m        /Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_04/IBSR_04.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      /Users/melikapooyan/Documents/elastix-5.0/resIBSR_04/
# -p        /Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt
# -p        /Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt
# -threads  unspecified, so all available threads are used
# WARNING: The parameter "UseDirectionCosines", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# WARNING: The option "UseDirectionCosines" was not found in your parameter file.
#   From elastix 4.8 it defaults to true!
# This may change the behavior of your registrations considerably.
#
# Command line options from TransformBase:
# -t0       unspecified, so no initial transform used
#
# Reading images...
# Reading images took 104 ms.
#
# WARNING: the fixed pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: the moving pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: The parameter "AutomaticTransformInitializationMethod", requested at entry number 0, does not exist at all.
#   The default value "GeometricalCenter" is used instead.
# Transform parameters are initialized as: [1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0]
# InitializeTransform took 0.00s
# WARNING: The parameter "AutomaticScalesEstimation", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Scales for transform parameters are: [50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 1, 1, 1]
# Initialization of all components (before registration) took: 0 ms.
# Preparation of the image pyramids took: 238 ms.
#
# Resolution: 0
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 0, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 0 ms.
#   Computing the moving image extrema took 0 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 5 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.408629	4.000000	0.778691	16.9
# 1	-0.427104	2.000000	0.735548	10.1
# 2	-0.433196	1.000000	0.769219	10.2
# 3	-0.439056	0.500000	0.777960	10.2
# Time spent in resolution 0 (ITK initialization and iterating): 0.058 s.
# Stopping condition: Minimum step size has been reached.
#
# Resolution: 1
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 1, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 1 ms.
#   Computing the moving image extrema took 1 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 41 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.409202	2.000000	0.616359	74.6
# 1	-0.411787	1.000000	0.616344	30.3
# 2	-0.416478	1.000000	0.650045	30.1
# 3	-0.423051	0.500000	0.582318	29.5
# 4	-0.425383	0.500000	0.541342	29.5
# 5	-0.427103	0.250000	0.475987	30.7
# 6	-0.427883	0.250000	0.443865	29.7
# 7	-0.429368	0.250000	0.441900	29.6
# 8	-0.434559	0.125000	0.335466	29.5
# 9	-0.434920	0.125000	0.342287	29.7
# 10	-0.435406	0.125000	0.328329	29.4
# 11	-0.436361	0.062500	0.252141	29.4
# 12	-0.436484	0.062500	0.251432	28.8
# 13	-0.436665	0.062500	0.253138	31.0
# 14	-0.437175	0.062500	0.235639	29.3
# Time spent in resolution 1 (ITK initialization and iterating): 0.521 s.
# Stopping condition: Minimum step size has been reached.
#
# Resolution: 2
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 2, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 10 ms.
#   Computing the moving image extrema took 10 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 385 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.378994	2.000000	0.221800	438.9
# 1	-0.373428	1.000000	0.134599	45.7
# 2	-0.378864	1.000000	0.095838	47.1
# 3	-0.379658	0.500000	0.247017	45.7
# 4	-0.380749	0.250000	0.131374	46.5
# 5	-0.380677	0.125000	0.187415	46.9
# 6	-0.380883	0.062500	0.166729	45.9
# Time spent in resolution 2 (ITK initialization and iterating): 0.764 s.
# Stopping condition: Minimum step size has been reached.
#
#
# Creating the TransformParameterFile took 0.00s
#
# Registration result checksum: 2058910356
# WARNING: The parameter "WriteResultImage", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# Applying final transform ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Applying final transform took 0.68s
#
# Final metric value  = -0.380935
# Time spent on saving the results, applying the final transform etc.: 678 ms.
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt", has finished.
#
#
# Current time: Tue Jan  2 18:39:48 2024.
# Time used for running elastix with this parameter file:
#   2.4s.
#
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 1: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt".
#
# Current time: Tue Jan  2 18:39:48 2024.
# Reading the elastix parameters from file ...
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        /Users/melikapooyan/Documents/elastix-5.0/IBSR_01/IBSR_01.nii.gz
# -m        /Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_04/IBSR_04.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      /Users/melikapooyan/Documents/elastix-5.0/resIBSR_04/
# -p        /Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt
# -p        /Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt
# -threads  unspecified, so all available threads are used
# WARNING: The parameter "UseDirectionCosines", requested at entry number 0, does not exist at all.
# ...
# 26	26	1	-0.550210	0.969053	0.000504	6.656244	0.000001	Main	true	true	WolfeSatisfied	41.7
# 27	27	0	-0.555338	2.000000	0.000973	4.962041	0.002186	Main	true	true	WolfeSatisfied	28.1
# 28	28	1	-0.552023	1.157425	0.000580	6.619980	-0.000061	Main	true	true	WolfeSatisfied	41.9
# 29	29	1	-0.559530	1.149604	0.000609	5.231966	-0.000133	Main	true	true	WolfeSatisfied	41.4
# Time spent in resolution 0 (ITK initialization and iterating): 1.035 s.
# Stopping condition: The gradient magnitude has (nearly) vanished.
#
# Resolution: 1
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "MaximumNumberOfLineSearchIterations", requested at entry number 1, does not exist at all.
#   The default value "20" is used instead.
# Elastix initialization of all components (for this resolution) took: 3 ms.
#   Computing the fixed image extrema took 1 ms.
#   Computing the moving image extrema took 1 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 40 ms.
# 1:ItNr	1a:SrchDirNr	1b:LineItNr	2:Metric	3:StepLength	4a:||Gradient||	4b:||SearchDir||	4c:DirGradient	5:Phase	6a:Wolfe1	6b:Wolfe2	7:LinSrchStopCondition	Time[ms]
# 0	0	1	-0.487942	5.000000	0.000980	1.000000	-0.000742	Main	true	true	WolfeSatisfied	128.7
# 1	1	0	-0.499013	1.000000	0.000961	5.851785	-0.002440	Main	true	true	WolfeSatisfied	49.4
# 2	2	1	-0.508485	4.143628	0.001210	5.860451	0.000371	Main	true	true	WolfeSatisfied	66.1
# 3	3	0	-0.497359	1.000000	0.000902	10.568982	-0.002539	Main	true	true	WolfeSatisfied	44.8
# 4	4	0	-0.506916	1.000000	0.000928	7.026154	-0.004030	Main	true	true	WolfeSatisfied	44.6
# 5	5	0	-0.502404	1.000000	0.000897	7.722547	-0.003268	Main	true	true	WolfeSatisfied	44.9
# 6	6	0	-0.506424	1.000000	0.000968	6.256821	-0.004398	Main	true	true	WolfeSatisfied	44.3
# 7	7	0	-0.512275	1.000000	0.000972	10.550797	-0.002769	Main	true	true	WolfeSatisfied	45.5
# 8	8	0	-0.504118	1.000000	0.000928	7.833516	-0.002977	Main	true	true	WolfeSatisfied	45.7
# 9	9	0	-0.507225	1.000000	0.001003	7.827632	-0.003221	Main	true	true	WolfeSatisfied	45.2
# 10	10	0	-0.510493	1.000000	0.000953	7.306897	-0.003142	Main	true	true	WolfeSatisfied	45.2
# 11	11	0	-0.509206	1.000000	0.000885	7.725255	-0.002872	Main	true	true	WolfeSatisfied	45.0
# 12	12	0	-0.510855	1.000000	0.001089	16.132869	-0.001354	Main	true	true	WolfeSatisfied	46.0
# 13	13	0	-0.518655	1.000000	0.000848	8.504137	-0.003042	Main	true	true	WolfeSatisfied	45.4
# 14	14	0	-0.513127	1.000000	0.000963	10.156905	-0.001852	Main	true	true	WolfeSatisfied	45.5
# 15	15	0	-0.512073	1.000000	0.000976	10.526556	-0.003609	Main	true	true	WolfeSatisfied	45.9
# 16	16	0	-0.503684	1.000000	0.000923	9.224831	-0.001337	Main	true	true	WolfeSatisfied	45.6
# 71	71	0	-0.529108	1.000000	0.000990	7.296755	-0.003822	Main	true	true	WolfeSatisfied	46.0
# 72	72	0	-0.534417	1.000000	0.000986	8.856261	0.000041	Main	true	true	WolfeSatisfied	46.8
# 73	73	0	-0.526753	1.000000	0.000870	8.422542	-0.003019	Main	true	true	WolfeSatisfied	46.1
# 74	74	0	-0.531886	1.000000	0.000858	9.707051	-0.002944	Main	true	true	WolfeSatisfied	45.8
# Time spent in resolution 1 (ITK initialization and iterating): 3.544 s.
# Stopping condition: Maximum number of iterations has been reached.
#
# Resolution: 2
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "MaximumNumberOfLineSearchIterations", requested at entry number 2, does not exist at all.
#   The default value "20" is used instead.
# Elastix initialization of all components (for this resolution) took: 12 ms.
#   Computing the fixed image extrema took 10 ms.
#   Computing the moving image extrema took 10 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 375 ms.
# 1:ItNr	1a:SrchDirNr	1b:LineItNr	2:Metric	3:StepLength	4a:||Gradient||	4b:||SearchDir||	4c:DirGradient	5:Phase	6a:Wolfe1	6b:Wolfe2	7:LinSrchStopCondition	Time[ms]
# 0	0	0	-0.430022	5.000000	0.000708	1.000000	-0.000525	Main	true	true	WolfeSatisfied	611.2
# 1	1	0	-0.442898	5.000000	0.000762	6.524556	-0.000214	Main	true	true	WolfeSatisfied	147.6
# 2	2	1	-0.441432	1.935818	0.000791	15.891642	-0.000152	Main	true	true	WolfeSatisfied	222.8
# 3	3	0	-0.438557	5.000000	0.001058	17.298353	0.003290	Main	true	true	WolfeSatisfied	148.6
# 4	4	1	-0.433767	1.461701	0.000791	45.696214	0.004890	Main	true	true	WolfeSatisfied	221.5
# 5	5	1	-0.437896	1.545433	0.000958	40.100722	0.005811	Main	true	true	WolfeSatisfied	218.7
# 6	6	1	-0.444555	1.681915	0.000776	29.761329	0.001724	Main	true	true	WolfeSatisfied	230.4
# 7	7	1	-0.445731	1.552690	0.000833	30.070057	0.001962	Main	true	true	WolfeSatisfied	222.5
# 8	8	1	-0.453134	1.748218	0.000795	24.682820	0.000318	Main	true	true	WolfeSatisfied	221.1
# 9	9	1	-0.449008	1.694951	0.000824	23.720348	0.001124	Main	true	true	WolfeSatisfied	221.1
# 10	10	1	-0.451470	1.753421	0.000765	23.776569	0.001518	Main	true	true	WolfeSatisfied	222.6
# 11	11	1	-0.455432	1.805126	0.000855	21.990864	0.000292	Main	true	true	WolfeSatisfied	223.6
# 12	12	1	-0.454510	1.523102	0.000896	26.242692	0.003319	Main	true	true	WolfeSatisfied	220.8
# 13	13	1	-0.448263	1.601435	0.000824	22.423005	0.001215	Main	true	true	WolfeSatisfied	225.1
# 14	14	1	-0.458162	1.742262	0.000866	19.846899	0.000825	Main	true	true	WolfeSatisfied	223.6
# 15	15	1	-0.451735	1.771897	0.000839	19.184728	0.000663	Main	true	true	WolfeSatisfied	228.2
# 16	16	1	-0.454916	1.739465	0.000819	19.373743	0.000973	Main	true	true	WolfeSatisfied	226.6
# 17	17	1	-0.451255	1.694482	0.000851	20.059773	0.000405	Main	true	true	WolfeSatisfied	224.5
# 18	18	1	-0.446868	1.614973	0.000872	20.646906	0.002017	Main	true	true	WolfeSatisfied	228.3
# 19	19	1	-0.454916	1.723006	0.000811	18.627394	0.000745	Main	true	true	WolfeSatisfied	225.9
# 20	20	1	-0.450994	1.874844	0.000862	17.705840	0.000278	Main	true	true	WolfeSatisfied	227.2
# 21	21	1	-0.454265	1.720060	0.000889	18.010909	0.001418	Main	true	true	WolfeSatisfied	227.0
# 22	22	1	-0.461664	1.914681	0.000890	17.855224	-0.000510	Main	true	true	WolfeSatisfied	223.2
# 23	23	1	-0.454257	1.824954	0.000801	18.337461	-0.000158	Main	true	true	WolfeSatisfied	227.3
# 24	24	1	-0.454928	1.487139	0.000886	23.162471	0.002305	Main	true	true	WolfeSatisfied	225.0
# Time spent in resolution 2 (ITK initialization and iterating): 5.848 s.
# Stopping condition: Maximum number of iterations has been reached.
#
#
# Creating the TransformParameterFile took 0.05s
#
# Registration result checksum: 333091561
# WARNING: The parameter "WriteResultImage", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# Applying final transform ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Applying final transform took 2.02s
#
# Final metric value  = -0.450342
# Time spent on saving the results, applying the final transform etc.: 2072 ms.
# Running elastix with parameter file 1: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt", has finished.
#
#
# Current time: Tue Jan  2 18:40:31 2024.
# Time used for running elastix with this parameter file:
#   12.7s.
#
# -------------------------------------------------------------------------
#
# Total time elapsed: 15.3s.
#
#
# Elastix registration completed successfully.

# %% [markdown]
# Transformix

# %%
import subprocess
import os

def run_transformix(input_image_path, transform_param_file, output_dir):
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the Transformix command
    command = [
        transformix_path,
        '-in', input_image_path,
        '-out', output_dir,
        '-tp', transform_param_file
    ]

    # Execute the Transformix command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Check if Transformix ran successfully
    if result.returncode == 0:
        print(f'Transformix completed successfully for {input_image_path}.')
    else:
        print(f'Transformix failed for {input_image_path}.')
        print(result.stderr)

# Define paths
transformix_path = '/Users/melikapooyan/Documents/elastix-5.0/transformix'

# List of segmentation files and corresponding transform parameters and output directories
cases = [
    {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_03/IBSR_03_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/resIBSR_03/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/res_seg.IBSR03'
    },
    {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_04/IBSR_04_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/resIBSR_04/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/res_seg.IBSR04'
    },
    {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_05/IBSR_05_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/resIBSR_05/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/res_seg.IBSR05'
    },
    {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_06/IBSR_06_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/resIBSR_06/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/res_seg.IBSR06'
    }
    # Add the rest of the cases here following the same structure
]

for case in cases:
    run_transformix(case['seg_path'], case['transform_param_file'], case['output_dir'])
# Out:
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_03/IBSR_03_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_04/IBSR_04_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_05/IBSR_05_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/TVTSets/Training_Set/IBSR_06/IBSR_06_seg.nii.gz.
