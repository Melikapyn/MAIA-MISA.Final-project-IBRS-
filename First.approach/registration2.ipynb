# %% [markdown]
# Registration of atlas 1 to validation set

# %%
import subprocess
import os

# Define paths
elastix_path = '/Users/melikapooyan/Documents/elastix-5.0/elastix'  # Path to the Elastix executable
fixed_image_paths = [
    '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Validation_Set/IBSR_13/IBSR_13.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/TVTSets/Validation_Set/IBSR_14/IBSR_14.nii.gz'
]
moving_image_path = '/Users/melikapooyan/Documents/elastix-5.0/mean_sc1.nii.gz'  # Path to the moving image

param_file_path1 = '/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt'  # Path to the first parameter file
param_file_path2 = '/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.elastic.txt'  # Path to the second parameter file

output_dir_base = '/Users/melikapooyan/Documents/elastix-5.0/'  # Base output directory

for fixed_image_path in fixed_image_paths:
    # Extract the identifier of the fixed image for the output directory
    fixed_image_identifier = os.path.basename(fixed_image_path).split('.')[0].split('_')[1]
    output_dir = os.path.join(output_dir_base, f'resIBSR_{fixed_image_identifier}')

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the Elastix command with two parameter files
    command = [
        elastix_path,
        '-f', fixed_image_path,
        '-m', moving_image_path,
        '-out', output_dir,
        '-p', param_file_path1,
        '-p', param_file_path2
    ]

    # Execute the Elastix command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Print the output for debugging
    print(f"Registration with fixed image IBSR_{fixed_image_identifier}")
    print(result.stdout)

    # Check if Elastix ran successfully
    if result.returncode == 0:
        print(f'Elastix registration completed successfully for IBSR_{fixed_image_identifier}.')
    else:
        print(f'Elastix registration failed for IBSR_{fixed_image_identifier}.')
        print(result.stderr)
# Out:
# Registration with fixed image IBSR_13
#
# elastix is started at Tue Jan  2 18:55:03 2024.
#
# which elastix:   /Users/melikapooyan/Documents/elastix-5.0/elastix
# elastix runs at: pc-8-91.customer.ask4.lan
#   macOS 14.0 (x64), 23A344
#   with 16384 MB memory, and 8 cores @ 2400 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt".
#
# Current time: Tue Jan  2 18:55:03 2024.
# Reading the elastix parameters from file ...
#
# ERROR: could not read moving image.
#
# itk::ImageFileReaderException (0x7f81b69f9140)
# Location: "unknown"
# File: /Users/laosdirg/dev/ITK/Modules/IO/ImageBase/include/itkImageFileReader.hxx
# Line: 136
# Description:  Could not create IO object for reading file /Users/melikapooyan/Documents/elastix-5.0/mean_sc1.nii.gz
# The file doesn't exist.
# Filename = /Users/melikapooyan/Documents/elastix-5.0/mean_sc1.nii.gz
#
#
#
# Errors occurred!
#
# Elastix registration failed for IBSR_13.
#
# Registration with fixed image IBSR_14
#
# elastix is started at Tue Jan  2 18:55:03 2024.
#
# which elastix:   /Users/melikapooyan/Documents/elastix-5.0/elastix
# elastix runs at: pc-8-91.customer.ask4.lan
#   macOS 14.0 (x64), 23A344
#   with 16384 MB memory, and 8 cores @ 2400 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Parameters.Par0009.affine.txt".
#
# Current time: Tue Jan  2 18:55:03 2024.
# Reading the elastix parameters from file ...
#
# ERROR: could not read moving image.
#
# itk::ImageFileReaderException (0x7fa0df4093f0)
# Location: "unknown"
# File: /Users/laosdirg/dev/ITK/Modules/IO/ImageBase/include/itkImageFileReader.hxx
# Line: 136
# Description:  Could not create IO object for reading file /Users/melikapooyan/Documents/elastix-5.0/mean_sc1.nii.gz
# The file doesn't exist.
# Filename = /Users/melikapooyan/Documents/elastix-5.0/mean_sc1.nii.gz
#
#
#
# Errors occurred!
#
# Elastix registration failed for IBSR_14.

# %% [markdown]
# Transformix

# %%
import subprocess
import os

def run_transformix(input_image_path, transform_param_file, output_dir):
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the Transformix command
    command = [
        transformix_path,
        '-in', input_image_path,
        '-out', output_dir,
        '-tp', transform_param_file
    ]

    # Execute the Transformix command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Print both stdout and stderr for diagnostics
    print("Standard Output:", result.stdout)
    print("Error Output:", result.stderr)

    # Check if Transformix ran successfully
    if result.returncode == 0:
        print(f'Transformix completed successfully for {input_image_path}.')
    else:
        print(f'Transformix failed for {input_image_path}.')

# Define paths
transformix_path = '/Users/melikapooyan/Documents/elastix-5.0/transformix'
csf_map_path = '/Users/melikapooyan/Documents/elastix-5.0/Scanner1/atlas1/csf_1.nii.gz'
transform_param_file = '/Users/melikapooyan/Documents/elastix-5.0/resIBSR_14/TransformParameters.1.txt'
output_dir_csf = '/Users/melikapooyan/Documents/elastix-5.0/resIBSR_14/csf'

# Run Transformix for the CSF map
run_transformix(csf_map_path, transform_param_file, output_dir_csf)
# Out:
# Standard Output:
# transformix is started at Tue Jan  2 19:42:27 2024.
#
# which transformix:   /Users/melikapooyan/Documents/elastix-5.0/transformix
# transformix runs at: pc-8-91.customer.ask4.lan
#   macOS 14.0 (x64), 23A344
#   with 16384 MB memory, and 8 cores @ 2400 MHz.
# Running transformix with parameter file "/Users/melikapooyan/Documents/elastix-5.0/resIBSR_14/TransformParameters.1.txt".
#
# Reading the elastix parameters from file ...
#
# Installing all components.
# InstallingComponents was successful.
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -in       /Users/melikapooyan/Documents/elastix-5.0/Scanner1/atlas1/csf_1.nii.gz
# -out      /Users/melikapooyan/Documents/elastix-5.0/resIBSR_14/csf/
# -threads  unspecified, so all available threads are used
# -tp       /Users/melikapooyan/Documents/elastix-5.0/resIBSR_14/TransformParameters.1.txt
# -def      unspecified, so no input points transformed
# -jac      unspecified, so no det(dT/dx) computed
# -jacmat   unspecified, so no dT/dx computed
#
# Reading input image ...
#   Reading input image took 0.025118 s
# Calling all ReadFromFile()'s ...
# Reading the elastix parameters from file ...
#
#   Calling all ReadFromFile()'s took 0.026858 s
# Transforming points ...
#   The command-line option "-def" is not used, so no points are transformed
#   Transforming points done, it took 0.00s
# Compute determinant of spatial Jacobian ...
#   The command-line option "-jac" is not used, so no det(dT/dx) computed.
#   Computing determinant of spatial Jacobian done, it took 0.00s
# Compute spatial Jacobian (full matrix) ...
#   The command-line option "-jacmat" is not used, so no dT/dx computed.
#   Computing spatial Jacobian done, it took 0.00s
# Resampling image and writing to disk ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Resampling took 1.96s
#
# transformix has finished at Tue Jan  2 19:42:30 2024.
# Total time elapsed: 2.1s.
#
#
# Error Output:
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Scanner1/atlas1/csf_1.nii.gz.
