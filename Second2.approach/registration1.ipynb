# %% [markdown]
# Preprocessed of Second method multiple atlases using all traingset and register them to each validationset

# %% [markdown]
# Elastix
# registration of all training dataset

# %%
import subprocess
import os

# Define paths
elastix_path = '/Users/melikapooyan/Documents/elastix-5.0/elastix'  # Path to the Elastix executable
fixed_image_path = '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Validation_Set/IBSR_17/IBSR_17_preprocessed.nii.gz'  # Path to the fixed image

# List of moving images
moving_image_paths = [
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_01/IBSR_01_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_03/IBSR_03_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_04/IBSR_04_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_05/IBSR_05_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_06/IBSR_06_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_07/IBSR_07_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_08/IBSR_08_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_09/IBSR_09_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_16/IBSR_16_preprocessed.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_18/IBSR_18_preprocessed.nii.gz'
]

output_dir_base = '/Users/melikapooyan/Documents/elastix-5.0/Misa.course'  # Base output directory
param_file_path1 = '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt'  # Path to the first parameter file
param_file_path2 = '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.elastic.txt'  # Path to the second parameter file

for moving_image_path in moving_image_paths:
    # Extract the identifier of the moving image for the output directory
    moving_image_identifier = os.path.basename(moving_image_path).split('.')[0].split('_')[1]
    output_dir = os.path.join(output_dir_base, f'resIBSR_{moving_image_identifier}')

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the Elastix command with two parameter files
    command = [
        elastix_path,
        '-f', fixed_image_path,
        '-m', moving_image_path,
        '-out', output_dir,
        '-p', param_file_path1,
        '-p', param_file_path2
    ]

    # Execute the Elastix command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Print the output for debugging
    print(f"Registration of IBSR_{moving_image_identifier}")
    print(result.stdout)

    # Check if Elastix ran successfully
    if result.returncode == 0:
        print('Elastix registration completed successfully.')
    else:
        print('Elastix registration failed.')
        print(result.stderr)
# Out:
# Registration of IBSR_01
#
# elastix is started at Thu Jan 11 18:43:08 2024.
#
# which elastix:   /Users/melikapooyan/Documents/elastix-5.0/elastix
# elastix runs at: pc-8-91.customer.ask4.lan
#   macOS 14.0 (x64), 23A344
#   with 16384 MB memory, and 8 cores @ 2400 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt".
#
# Current time: Thu Jan 11 18:43:08 2024.
# Reading the elastix parameters from file ...
#
# Installing all components.
# InstallingComponents was successful.
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Validation_Set/IBSR_17/IBSR_17_preprocessed.nii.gz
# -m        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_01/IBSR_01_preprocessed.nii.gz
# ...

# %% [markdown]
# Transformix

# %%
import subprocess
import os

def run_transformix(input_image_path, transform_param_file, output_dir):
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the Transformix command
    command = [
        transformix_path,
        '-in', input_image_path,
        '-out', output_dir,
        '-tp', transform_param_file
    ]

    # Execute the Transformix command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Check if Transformix ran successfully
    if result.returncode == 0:
        print(f'Transformix completed successfully for {input_image_path}.')
    else:
        print(f'Transformix failed for {input_image_path}.')
        print(result.stderr)

# Define paths
transformix_path = '/Users/melikapooyan/Documents/elastix-5.0/transformix'

# List of segmentation files and corresponding transform parameters and output directories
cases = [
        {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_01/IBSR_01_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_01/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_01/res_seg.IBSR01'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_03/IBSR_03_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_03/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_03/res_seg.IBSR03'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_04/IBSR_04_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_04/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_04/res_seg.IBSR04'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_05/IBSR_05_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_05/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_05/res_seg.IBSR05'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_06/IBSR_06_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_06/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_06/res_seg.IBSR06'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_07/IBSR_07_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_07/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_07/res_seg.IBSR07'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_08/IBSR_08_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_08/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_08/res_seg.IBSR08'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_09/IBSR_09_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_09/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_09/res_seg.IBSR09'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_16/IBSR_16_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_16/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_16/res_seg.IBSR16'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_18/IBSR_18_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_18/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_18/res_seg.IBSR18'
    }

]

for case in cases:
    run_transformix(case['seg_path'], case['transform_param_file'], case['output_dir'])
# Out:
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_01/IBSR_01_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_03/IBSR_03_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_04/IBSR_04_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_05/IBSR_05_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_06/IBSR_06_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/pre.Training_Set/IBSR_07/IBSR_07_seg.nii.gz.
# ...
