# %% [markdown]
# Second method multiple atlases using all traingset and register them to each validationset

# %% [markdown]
# Elastix
# registration of all training dataset

# %%
import subprocess
import os

# Define paths
elastix_path = '/Users/melikapooyan/Documents/elastix-5.0/elastix'  # Path to the Elastix executable
fixed_image_path = '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Validation_Set/IBSR_17/IBSR_17.nii.gz'  # Path to the fixed image

# List of moving images
moving_image_paths = [
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_01/IBSR_01.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_03/IBSR_03.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_04/IBSR_04.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_05/IBSR_05.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_06/IBSR_06.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_07/IBSR_07.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_08/IBSR_08.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_09/IBSR_09.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_16/IBSR_16.nii.gz',
    '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_18/IBSR_18.nii.gz'
]

output_dir_base = '/Users/melikapooyan/Documents/elastix-5.0/Misa.course'  # Base output directory
param_file_path1 = '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt'  # Path to the first parameter file
param_file_path2 = '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.elastic.txt'  # Path to the second parameter file

for moving_image_path in moving_image_paths:
    # Extract the identifier of the moving image for the output directory
    moving_image_identifier = os.path.basename(moving_image_path).split('.')[0].split('_')[1]
    output_dir = os.path.join(output_dir_base, f'resIBSR_{moving_image_identifier}')

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the Elastix command with two parameter files
    command = [
        elastix_path,
        '-f', fixed_image_path,
        '-m', moving_image_path,
        '-out', output_dir,
        '-p', param_file_path1,
        '-p', param_file_path2
    ]

    # Execute the Elastix command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Print the output for debugging
    print(f"Registration of IBSR_{moving_image_identifier}")
    print(result.stdout)

    # Check if Elastix ran successfully
    if result.returncode == 0:
        print('Elastix registration completed successfully.')
    else:
        print('Elastix registration failed.')
        print(result.stderr)
# Out:
# Registration of IBSR_01
#
# elastix is started at Wed Jan  3 20:39:15 2024.
#
# which elastix:   /Users/melikapooyan/Documents/elastix-5.0/elastix
# elastix runs at: pc-8-91.customer.ask4.lan
#   macOS 14.0 (x64), 23A344
#   with 16384 MB memory, and 8 cores @ 2400 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt".
#
# Current time: Wed Jan  3 20:39:15 2024.
# Reading the elastix parameters from file ...
#
# Installing all components.
# InstallingComponents was successful.
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Validation_Set/IBSR_17/IBSR_17.nii.gz
# -m        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_01/IBSR_01.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      /Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_01/
# -p        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt
# -p        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.elastic.txt
# -threads  unspecified, so all available threads are used
# WARNING: The parameter "UseDirectionCosines", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# WARNING: The option "UseDirectionCosines" was not found in your parameter file.
#   From elastix 4.8 it defaults to true!
# This may change the behavior of your registrations considerably.
#
# Command line options from TransformBase:
# -t0       unspecified, so no initial transform used
#
# Reading images...
# Reading images took 105 ms.
#
# WARNING: the fixed pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: the moving pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: The parameter "AutomaticTransformInitializationMethod", requested at entry number 0, does not exist at all.
#   The default value "GeometricalCenter" is used instead.
# Transform parameters are initialized as: [1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0]
# InitializeTransform took 0.00s
# WARNING: The parameter "AutomaticScalesEstimation", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Scales for transform parameters are: [50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 1, 1, 1]
# Initialization of all components (before registration) took: 0 ms.
# Preparation of the image pyramids took: 242 ms.
#
# Resolution: 0
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 0, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 0 ms.
#   Computing the moving image extrema took 0 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 5 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.294756	4.000000	0.274638	17.7
# 1	-0.346783	4.000000	0.294794	11.4
# 2	-0.407079	4.000000	0.373452	10.8
# 3	-0.471273	4.000000	0.494614	11.3
# 4	-0.510004	4.000000	0.809039	11.5
# 5	-0.515847	2.000000	0.825712	10.3
# 6	-0.524895	2.000000	0.839442	10.9
# 7	-0.529306	1.000000	0.647252	11.1
# 8	-0.534663	1.000000	0.726999	10.8
# 9	-0.538743	0.500000	0.736776	10.9
# Time spent in resolution 0 (ITK initialization and iterating): 0.128 s.
# Stopping condition: Minimum step size has been reached.
#
# Resolution: 1
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 1, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 1 ms.
#   Computing the moving image extrema took 1 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 42 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.502159	2.000000	0.600459	78.6
# 1	-0.498868	1.000000	0.348081	32.7
# 2	-0.509528	1.000000	0.368152	32.6
# 3	-0.513488	0.500000	0.394522	33.0
# 4	-0.514634	0.250000	0.479248	32.6
# 5	-0.515128	0.125000	0.439986	32.4
# 6	-0.516239	0.062500	0.457212	32.3
# 7	-0.516586	0.062500	0.457959	32.4
# 8	-0.517922	0.062500	0.420611	32.0
# 9	-0.518131	0.062500	0.436505	30.8
# 10	-0.518607	0.062500	0.445205	30.9
# 11	-0.519559	0.062500	0.418701	30.0
# Time spent in resolution 1 (ITK initialization and iterating): 0.464 s.
# Stopping condition: Minimum step size has been reached.
#
# Resolution: 2
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 2, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 12 ms.
#   Computing the moving image extrema took 11 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 372 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.450185	2.000000	0.446796	433.1
# 1	-0.443198	1.000000	0.276639	52.0
# 2	-0.453478	1.000000	0.338397	52.5
# 3	-0.457822	0.500000	0.284063	52.2
# 4	-0.458719	0.250000	0.246658	51.3
# 5	-0.459414	0.250000	0.187897	49.8
# 6	-0.459528	0.125000	0.173910	50.1
# 7	-0.459995	0.062500	0.175310	48.3
# 8	-0.460146	0.062500	0.182313	48.9
# 9	-0.460344	0.062500	0.185686	48.8
# Time spent in resolution 2 (ITK initialization and iterating): 0.939 s.
# Stopping condition: Minimum step size has been reached.
#
#
# Creating the TransformParameterFile took 0.00s
#
# Registration result checksum: 3193842844
# WARNING: The parameter "WriteResultImage", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# Applying final transform ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Applying final transform took 0.66s
#
# Final metric value  = -0.460534
# Time spent on saving the results, applying the final transform etc.: 659 ms.
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt", has finished.
#
#
# Current time: Wed Jan  3 20:39:18 2024.
# Time used for running elastix with this parameter file:
#   2.5s.
#
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 1: "/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.elastic.txt".
#
# Current time: Wed Jan  3 20:39:18 2024.
# Reading the elastix parameters from file ...
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Validation_Set/IBSR_17/IBSR_17.nii.gz
# -m        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_01/IBSR_01.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      /Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_01/
# -p        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt
# -p        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.elastic.txt
# -threads  unspecified, so all available threads are used
# WARNING: The parameter "UseDirectionCosines", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# WARNING: The option "UseDirectionCosines" was not found in your parameter file.
#   From elastix 4.8 it defaults to true!
# This may change the behavior of your registrations considerably.
#
# Command line options from TransformBase:
# -t0       unspecified, so no initial transform used
# WARNING: The parameter "BSplineTransformSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseCyclicTransform", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
#
# Reading images...
# Reading images took 0 ms.
#
# WARNING: the fixed pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: the moving pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: The parameter "GenerateLineSearchIterations", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Initialization of all components (before registration) took: 4 ms.
# Preparation of the image pyramids took: 230 ms.
#
# Resolution: 0
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "MaximumNumberOfLineSearchIterations", requested at entry number 0, does not exist at all.
#   The default value "20" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 0 ms.
#   Computing the moving image extrema took 0 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 5 ms.
# 1:ItNr	1a:SrchDirNr	1b:LineItNr	2:Metric	3:StepLength	4a:||Gradient||	4b:||SearchDir||	4c:DirGradient	5:Phase	6a:Wolfe1	6b:Wolfe2	7:LinSrchStopCondition	Time[ms]
# 0	0	2	-0.628160	42.000000	0.001972	1.000000	0.000440	Main	true	true	WolfeSatisfied	76.1
# 1	1	1	-0.638379	0.740744	0.001161	21.033454	-0.000894	Main	true	true	WolfeSatisfied	40.6
# 2	2	0	-0.646490	2.000000	0.001323	7.665020	0.002002	Main	true	true	WolfeSatisfied	27.0
# 3	3	0	-0.660665	2.000000	0.000931	8.461386	-0.000758	Main	true	true	WolfeSatisfied	27.4
# 4	4	1	-0.651556	0.969212	0.000930	15.723105	-0.000591	Main	true	true	WolfeSatisfied	40.2
# 5	5	0	-0.669592	2.000000	0.001357	8.142091	0.004268	Main	true	true	WolfeSatisfied	28.3
# 6	6	1	-0.660910	1.164826	0.000798	8.175154	0.000293	Main	true	true	WolfeSatisfied	42.6
# 7	7	0	-0.663005	2.000000	0.000857	6.923706	0.001109	Main	true	true	WolfeSatisfied	28.5
# 8	8	1	-0.672335	0.897106	0.000706	9.596930	-0.000680	Main	true	true	WolfeSatisfied	41.2
# 9	9	1	-0.658338	1.163432	0.000638	7.087726	0.000147	Main	true	true	WolfeSatisfied	40.6
# 10	10	0	-0.661315	2.000000	0.000883	5.842200	0.000805	Main	true	true	WolfeSatisfied	27.9
# 11	11	0	-0.671045	2.000000	0.001070	6.056686	0.003401	Main	true	true	WolfeSatisfied	27.1
# 12	12	0	-0.668287	2.000000	0.001094	7.617107	0.003768	Main	true	true	WolfeSatisfied	26.7
# 13	13	0	-0.657152	2.000000	0.001131	7.057326	0.004309	Main	true	true	WolfeSatisfied	27.8
# 14	14	1	-0.677360	1.057976	0.000671	9.720829	0.000114	Main	true	true	WolfeSatisfied	39.6
# 15	15	0	-0.674884	2.000000	0.000969	5.963000	0.002282	Main	true	true	WolfeSatisfied	27.6
# 16	16	0	-0.659449	2.000000	0.000963	8.084584	0.003362	Main	true	true	WolfeSatisfied	29.1
# 17	17	1	-0.669493	1.034718	0.000557	10.909114	-0.000172	Main	true	true	WolfeSatisfied	41.0
# 18	18	1	-0.669063	1.141502	0.000572	6.434308	-0.000055	Main	true	true	WolfeSatisfied	42.6
# 19	19	0	-0.659176	2.000000	0.000795	5.725926	0.001568	Main	true	true	WolfeSatisfied	27.2
# 20	20	1	-0.667340	1.022694	0.000605	10.324040	-0.000084	Main	true	true	WolfeSatisfied	42.2
# Time spent in resolution 0 (ITK initialization and iterating): 0.754 s.
# Stopping condition: The gradient magnitude has (nearly) vanished.
#
# Resolution: 1
# WARNING: The parameter "ShowExactMetricValue", requested at entry number
requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# Applying final transform ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Applying final transform took 1.93s
#
# Final metric value  = -0.574369
# Time spent on saving the results, applying the final transform etc.: 1977 ms.
# Running elastix with parameter file 1: "/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.elastic.txt", has finished.
#
#
# Current time: Wed Jan  3 20:39:29 2024.
# Time used for running elastix with this parameter file:
#   11.9s.
#
# -------------------------------------------------------------------------
#
# Total time elapsed: 14.5s.
#
#
# Elastix registration completed successfully.
# Registration of IBSR_03
#
# elastix is started at Wed Jan  3 20:39:30 2024.
#
# which elastix:   /Users/melikapooyan/Documents/elastix-5.0/elastix
# elastix runs at: pc-8-91.customer.ask4.lan
#   macOS 14.0 (x64), 23A344
#   with 16384 MB memory, and 8 cores @ 2400 MHz.
# -------------------------------------------------------------------------
#
# Running elastix with parameter file 0: "/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt".
#
# Current time: Wed Jan  3 20:39:30 2024.
# Reading the elastix parameters from file ...
#
# Installing all components.
# InstallingComponents was successful.
#
# ELASTIX version: 5.000
# Command line options from ElastixBase:
# -f        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Validation_Set/IBSR_17/IBSR_17.nii.gz
# -m        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_03/IBSR_03.nii.gz
# -fMask    unspecified, so no fixed mask used
# -mMask    unspecified, so no moving mask used
# -out      /Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_03/
# -p        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.affine.txt
# -p        /Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.elastic.txt
# -threads  unspecified, so all available threads are used
# WARNING: The parameter "UseDirectionCosines", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# WARNING: The option "UseDirectionCosines" was not found in your parameter file.
#   From elastix 4.8 it defaults to true!
# This may change the behavior of your registrations considerably.
#
# Command line options from TransformBase:
# -t0       unspecified, so no initial transform used
#
# Reading images...
# Reading images took 110 ms.
#
# WARNING: the fixed pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: the moving pyramid schedule is not fully specified!
#   A default pyramid schedule is used.
# WARNING: The parameter "AutomaticTransformInitializationMethod", requested at entry number 0, does not exist at all.
#   The default value "GeometricalCenter" is used instead.
# Transform parameters are initialized as: [1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0]
# InitializeTransform took 0.00s
# WARNING: The parameter "AutomaticScalesEstimation", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Scales for transform parameters are: [50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 1, 1, 1]
# Initialization of all components (before registration) took: 0 ms.
# Preparation of the image pyramids took: 237 ms.
#
# Resolution: 0
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 0, does not exist at all.
#   The default value "16" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 0, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 0, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 0, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 0, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 0 ms.
#   Computing the moving image extrema took 0 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 5 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.254019	4.000000	0.290738	17.7
# 1	-0.299473	4.000000	0.408364	10.7
# 2	-0.348867	4.000000	0.508224	10.0
# 3	-0.396943	4.000000	0.694978	10.4
# 4	-0.429444	4.000000	0.940546	10.4
# 5	-0.456211	2.000000	1.063218	10.0
# 6	-0.469499	1.000000	1.090830	10.4
# 7	-0.482393	0.500000	1.118596	10.0
# 8	-0.486698	0.500000	1.128403	10.8
# Time spent in resolution 0 (ITK initialization and iterating): 0.112 s.
# Stopping condition: Minimum step size has been reached.
#
# Resolution: 1
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 1, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 1 ms.
#   Computing the moving image extrema took 1 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 41 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.463229	2.000000	0.984544	72.5
# 1	-0.475144	1.000000	1.060176	28.6
# 2	-0.482113	0.500000	0.978487	28.3
# 3	-0.486564	0.250000	1.002162	28.3
# 4	-0.490066	0.125000	0.937180	28.8
# 5	-0.491654	0.125000	0.934778	28.5
# 6	-0.494146	0.125000	0.931508	28.1
# 7	-0.496246	0.125000	0.927269	28.3
# 8	-0.500548	0.125000	0.872706	28.6
# 9	-0.508862	0.125000	0.780230	28.0
# 10	-0.510108	0.125000	0.789843	28.4
# 11	-0.511211	0.125000	0.802961	29.2
# 12	-0.512582	0.125000	0.811953	28.5
# 13	-0.515329	0.062500	0.777589	29.3
# Time spent in resolution 1 (ITK initialization and iterating): 0.472 s.
# Stopping condition: Minimum step size has been reached.
#
# Resolution: 2
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "NewSamplesEveryIteration", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "RelaxationFactor", requested at entry number 2, does not exist at all.
#   The default value "0.5" is used instead.
# Elastix initialization of all components (for this resolution) took: 0 ms.
#   Computing the fixed image extrema took 11 ms.
#   Computing the moving image extrema took 11 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 439 ms.
# 1:ItNr	2:Metric	3:StepSize	4:||Gradient||	Time[ms]
# 0	-0.450438	2.000000	0.400717	496.2
# 1	-0.444240	1.000000	0.540456	52.9
# 2	-0.452426	1.000000	0.499995	51.3
# 3	-0.454002	0.500000	0.392150	49.2
# 4	-0.455092	0.250000	0.378817	50.7
# 5	-0.456118	0.125000	0.384519	48.4
# 6	-0.456470	0.125000	0.350298	53.2
# 7	-0.456985	0.062500	0.307777	49.1
# 8	-0.457156	0.062500	0.337164	57.1
# Time spent in resolution 2 (ITK initialization and iterating): 0.966 s.
# Stopping condition: Minimum step size has been reached.
#
#
# Creating the TransformParameterFile took 0.00s
#
# Registration result checksum: 260302777
# WARNING: The parameter "WriteResultImage", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# Applying final transform ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Applying final transform took 0.62s
#
# Final metric value  = -0.457488
# Time spent on saving the results, applying the final transform etc.: 622 ms.
# ...
# 15	15	1	-0.661325	1.151209	0.000633	9.537541	-0.000457	Main	true	true	WolfeSatisfied	44.8
# 16	16	0	-0.658317	2.000000	0.000921	6.353239	0.002683	Main	true	true	WolfeSatisfied	30.9
# 17	17	0	-0.653726	2.000000	0.001051	9.264013	0.005834	Main	true	true	WolfeSatisfied	30.4
# 18	18	1	-0.657163	1.039683	0.000589	11.193711	-0.000038	Main	true	true	WolfeSatisfied	45.0
# Time spent in resolution 0 (ITK initialization and iterating): 0.740 s.
# Stopping condition: The gradient magnitude has (nearly) vanished.
#
# Resolution: 1
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 1, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 1, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 1, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 1, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 1, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "MaximumNumberOfLineSearchIterations", requested at entry number 1, does not exist at all.
#   The default value "20" is used instead.
# Elastix initialization of all components (for this resolution) took: 3 ms.
#   Computing the fixed image extrema took 1 ms.
#   Computing the moving image extrema took 1 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 50 ms.
# 1:ItNr	1a:SrchDirNr	1b:LineItNr	2:Metric	3:StepLength	4a:||Gradient||	4b:||SearchDir||	4c:DirGradient	5:Phase	6a:Wolfe1	6b:Wolfe2	7:LinSrchStopCondition	Time[ms]
# 0	0	2	-0.608059	21.000000	0.000914	1.000000	-0.000297	Main	true	true	WolfeSatisfied	167.1
# 1	1	0	-0.613145	1.000000	0.001002	16.486664	-0.007970	Main	true	true	WolfeSatisfied	48.6
# 2	2	0	-0.611857	1.000000	0.000973	24.980200	-0.002881	Main	true	true	WolfeSatisfied	49.8
# 3	3	0	-0.634018	1.000000	0.000943	18.685821	-0.002510	Main	true	true	WolfeSatisfied	47.8
# 4	4	0	-0.608260	1.000000	0.000837	15.162568	-0.003673	Main	true	true	WolfeSatisfied	49.1
# 5	5	0	-0.630084	1.000000	0.000832	11.281313	-0.004901	Main	true	true	WolfeSatisfied	48.4
# 6	6	0	-0.630838	1.000000	0.000956	16.758473	-0.004716	Main	true	true	WolfeSatisfied	48.1
# 7	7	0	-0.633266	1.000000	0.000869	14.025329	-0.003754	Main	true	true	WolfeSatisfied	48.4
# 64	64	0	-0.656488	1.000000	0.000943	10.793730	-0.003255	Main	true	true	WolfeSatisfied	50.0
# 65	65	0	-0.647782	1.000000	0.000862	8.188467	-0.004363	Main	true	true	WolfeSatisfied	49.4
# 66	66	0	-0.671780	1.000000	0.000946	10.679860	-0.000694	Main	true	true	WolfeSatisfied	49.8
# 67	67	0	-0.659220	1.000000	0.000899	10.718691	-0.003757	Main	true	true	WolfeSatisfied	50.2
# 68	68	0	-0.666401	1.000000	0.000812	8.818478	-0.002933	Main	true	true	WolfeSatisfied	49.8
# 69	69	0	-0.654566	1.000000	0.000888	10.105088	-0.003360	Main	true	true	WolfeSatisfied	50.1
# 70	70	0	-0.660142	1.000000	0.000796	9.174612	-0.002236	Main	true	true	WolfeSatisfied	49.8
# 71	71	0	-0.669974	1.000000	0.000846	10.369088	-0.003558	Main	true	true	WolfeSatisfied	51.9
# 72	72	0	-0.665332	1.000000	0.000840	9.958283	-0.001897	Main	true	true	WolfeSatisfied	50.7
# 73	73	0	-0.668377	1.000000	0.000833	9.573570	-0.003780	Main	true	true	WolfeSatisfied	50.1
# 74	74	0	-0.666450	1.000000	0.000817	8.962338	-0.003425	Main	true	true	WolfeSatisfied	49.7
# Time spent in resolution 1 (ITK initialization and iterating): 3.858 s.
# Stopping condition: Maximum number of iterations has been reached.
#
# Resolution: 2
# WARNING: The parameter "ShowExactMetricValue", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "CheckNumberOfSamples", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseMultiThreadingForMetrics", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# Setting the fixed masks took: 0 ms.
# Setting the moving masks took: 0 ms.
# WARNING: The parameter "NumberOfFixedHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "NumberOfMovingHistogramBins", requested at entry number 2, does not exist at all.
#   The default value "32" is used instead.
# WARNING: The parameter "FixedLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "MovingLimitRangeRatio", requested at entry number 2, does not exist at all.
#   The default value "0.01" is used instead.
# WARNING: The parameter "FixedKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "0" is used instead.
# WARNING: The parameter "MovingKernelBSplineOrder", requested at entry number 2, does not exist at all.
#   The default value "3" is used instead.
# WARNING: The parameter "UseFastAndLowMemoryVersion", requested at entry number 2, does not exist at all.
#   The default value "true" is used instead.
# WARNING: The parameter "UseJacobianPreconditioning", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "FiniteDifferenceDerivative", requested at entry number 2, does not exist at all.
#   The default value "false" is used instead.
# WARNING: The parameter "MaximumNumberOfLineSearchIterations", requested at entry number 2, does not exist at all.
#   The default value "20" is used instead.
# Elastix initialization of all components (for this resolution) took: 11 ms.
#   Computing the fixed image extrema took 10 ms.
#   Computing the moving image extrema took 10 ms.
# Initialization of AdvancedMattesMutualInformation metric took: 360 ms.
# 1:ItNr	1a:SrchDirNr	1b:LineItNr	2:Metric	3:StepLength	4a:||Gradient||	4b:||SearchDir||	4c:DirGradient	5:Phase	6a:Wolfe1	6b:Wolfe2	7:LinSrchStopCondition	Time[ms]
# 0	0	1	-0.556081	17.307497	0.000603	1.000000	-0.000367	Main	true	true	WolfeSatisfied	647.7
# 1	1	0	-0.558135	5.000000	0.001156	18.987249	0.005734	Main	true	true	WolfeSatisfied	150.0
# 2	2	1	-0.555104	1.381992	0.000888	53.320155	0.009187	Main	true	true	WolfeSatisfied	222.4
# 3	3	1	-0.569070	1.437310	0.000997	39.534499	0.001685	Main	true	true	WolfeSatisfied	230.3
# 4	4	1	-0.564277	1.695166	0.000811	25.842994	0.001099	Main	true	true	WolfeSatisfied	233.0
# 5	5	1	-0.567373	1.555924	0.000916	28.637329	0.004012	Main	true	true	WolfeSatisfied	226.4
# 6	6	1	-0.570551	1.489737	0.000958	25.600281	0.002387	Main	true	true	WolfeSatisfied	228.4
# 7	7	1	-0.569316	1.805296	0.000801	20.071405	0.000665	Main	true	true	WolfeSatisfied	233.8
# 8	8	1	-0.573298	1.808696	0.000831	20.731796	0.000792	Main	true	true	WolfeSatisfied	230.7
# 9	9	1	-0.574413	1.694102	0.000833	21.969384	0.001283	Main	true	true	WolfeSatisfied	232.7
# 10	10	1	-0.569698	1.699823	0.000871	21.572843	0.000664	Main	true	true	WolfeSatisfied	232.6
# 11	11	1	-0.575444	1.804797	0.000836	20.039663	-0.000236	Main	true	true	WolfeSatisfied	227.8
# 12	12	1	-0.577026	1.684951	0.000938	22.680799	0.001866	Main	true	true	WolfeSatisfied	229.8
# 13	13	1	-0.575512	1.848228	0.000890	20.195660	0.000997	Main	true	true	WolfeSatisfied	232.4
# 14	14	1	-0.578084	1.587553	0.000815	20.180803	0.000629	Main	true	true	WolfeSatisfied	232.0
# 15	15	1	-0.575677	1.718764	0.000856	17.921342	0.001643	Main	true	true	WolfeSatisfied	234.7
# 16	16	1	-0.577772	1.589182	0.000783	20.871998	0.000553	Main	true	true	WolfeSatisfied	232.5
# 17	17	1	-0.585774	1.640747	0.000931	22.878704	0.002665	Main	true	true	WolfeSatisfied	232.8
# 18	18	1	-0.581642	1.636193	0.000809	21.047025	0.001147	Main	true	true	WolfeSatisfied	232.0
# 19	19	1	-0.587684	1.666261	0.000882	22.891473	0.001450	Main	true	true	WolfeSatisfied	236.9
# 20	20	1	-0.582841	1.637575	0.001053	21.040250	0.002400	Main	true	true	WolfeSatisfied	275.7
# 21	21	1	-0.582012	1.747581	0.000852	17.685610	0.000496	Main	true	true	WolfeSatisfied	259.3
# 22	22	1	-0.586238	1.846365	0.000863	16.859958	0.000448	Main	true	true	WolfeSatisfied	232.2
# 23	23	1	-0.590808	1.658069	0.000875	18.698928	0.000775	Main	true	true	WolfeSatisfied	234.9
# 24	24	1	-0.581591	1.763500	0.000905	17.267382	0.001111	Main	true	true	WolfeSatisfied	236.5
# Time spent in resolution 2 (ITK initialization and iterating): 6.201 s.
# Stopping condition: Maximum number of iterations has been reached.
#
#
# Creating the TransformParameterFile took 0.05s
#
# Registration result checksum: 2048505327
# WARNING: The parameter "WriteResultImage", requested at entry number 0, does not exist at all.
#   The default value "true" is used instead.
#
# Applying final transform ...
#
#   Progress: 0%
#   Progress: 3%
#   Progress: 6%
#   Progress: 9%
#   Progress: 13%
#   Progress: 16%
#   Progress: 19%
#   Progress: 22%
#   Progress: 25%
#   Progress: 28%
#   Progress: 31%
#   Progress: 34%
#   Progress: 38%
#   Progress: 41%
#   Progress: 44%
#   Progress: 47%
#   Progress: 50%
#   Progress: 53%
#   Progress: 56%
#   Progress: 59%
#   Progress: 63%
#   Progress: 66%
#   Progress: 69%
#   Progress: 72%
#   Progress: 75%
#   Progress: 78%
#   Progress: 81%
#   Progress: 84%
#   Progress: 88%
#   Progress: 91%
#   Progress: 94%
#   Progress: 97%
#   Progress: 100%
#   Progress: 100%
#   Writing image ...
#   Applying final transform took 2.13s
#
# Final metric value  = -0.580798
# Time spent on saving the results, applying the final transform etc.: 2185 ms.
# Running elastix with parameter file 1: "/Users/melikapooyan/Documents/elastix-5.0/Misa.course/Parameters.Par0009.elastic.txt", has finished.
#
#
# Current time: Wed Jan  3 20:41:53 2024.
# Time used for running elastix with this parameter file:
#   13.3s.
#
# -------------------------------------------------------------------------
#
# Total time elapsed: 15.6s.
#
#
# Elastix registration completed successfully.

# %% [markdown]
# Transformix

# %%
import subprocess
import os

def run_transformix(input_image_path, transform_param_file, output_dir):
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the Transformix command
    command = [
        transformix_path,
        '-in', input_image_path,
        '-out', output_dir,
        '-tp', transform_param_file
    ]

    # Execute the Transformix command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Check if Transformix ran successfully
    if result.returncode == 0:
        print(f'Transformix completed successfully for {input_image_path}.')
    else:
        print(f'Transformix failed for {input_image_path}.')
        print(result.stderr)

# Define paths
transformix_path = '/Users/melikapooyan/Documents/elastix-5.0/transformix'

# List of segmentation files and corresponding transform parameters and output directories
cases = [
        {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_01/IBSR_01_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_01/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_01/res_seg.IBSR01'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_03/IBSR_03_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_03/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_03/res_seg.IBSR03'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_04/IBSR_04_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_04/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_04/res_seg.IBSR04'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_05/IBSR_05_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_05/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_05/res_seg.IBSR05'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_06/IBSR_06_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_06/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_06/res_seg.IBSR06'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_07/IBSR_07_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_07/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_07/res_seg.IBSR07'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_08/IBSR_08_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_08/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_08/res_seg.IBSR08'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_09/IBSR_09_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_09/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_09/res_seg.IBSR09'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_16/IBSR_16_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_16/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_16/res_seg.IBSR16'
    },
            {
        'seg_path': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_18/IBSR_18_seg.nii.gz',
        'transform_param_file': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_18/TransformParameters.1.txt',
        'output_dir': '/Users/melikapooyan/Documents/elastix-5.0/Misa.course/resIBSR_18/res_seg.IBSR18'
    }

]

for case in cases:
    run_transformix(case['seg_path'], case['transform_param_file'], case['output_dir'])
# Out:
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_01/IBSR_01_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_03/IBSR_03_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_04/IBSR_04_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_05/IBSR_05_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_06/IBSR_06_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_07/IBSR_07_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_08/IBSR_08_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_09/IBSR_09_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_16/IBSR_16_seg.nii.gz.
# Transformix completed successfully for /Users/melikapooyan/Documents/elastix-5.0/Misa.course/TVTSets/Training_Set/IBSR_18/IBSR_18_seg.nii.gz.
